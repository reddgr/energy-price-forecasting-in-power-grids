# %%
import os
import glob
import pandas as pd
import random

from IPython.display import clear_output

ROOT = ".." # Adjust to repository root

# %% [markdown]
# ## Global Day-Ahead Electricity Price Dataset

# %% [markdown]
# This dataset presents a unified, cross-continental time-series day-ahead electricity prices compiled from major wholesale markets across Asia, Europe, North America, South America, and Oceania. The dataset offers a standardized format that supports time-series forecasting and enables robust comparative analysis across diverse global electricity markets.
#
# Ullah, Md Habib; Reza, Sayed Mohsin; Gundapaneni, Lasya Madhuri; Balachander, Pranav; Babaiahgari, Bhanu; Khan, Abdullah Al Ahad (2025), “Global Day-Ahead Electricity Price Dataset”, Mendeley Data, V3, doi: 10.17632/s54n4tyyz4.3
# https://data.mendeley.com/datasets/s54n4tyyz4/3

# %% [markdown]
# Creating a files index:

# %%
# Find all CSV files in the datasets/daep/ directory and subdirectories
csv_files = glob.glob(os.path.join(ROOT, 'datasets', 'daep', '**', '*.csv'), recursive=True)

# Create a list to store the results
results = []

# For each CSV file, get the file name and record count
for file_path in csv_files:
    file_name = os.path.basename(file_path)
    # Read the CSV file to get the record count
    df = pd.read_csv(file_path)
    record_count = len(df)
    results.append({'csv_name': file_name, 'record_count': record_count})
    print(f"Processed {file_name} with {record_count} records.")
    clear_output(wait=True)

    # Convert Timestamp column to datetime if it exists
    if 'Timestamp' in df.columns:
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])

    # Save as pickle file if it doesn't already exist
    pickle_file = os.path.join(ROOT, 'pkl', 'daep', file_name.replace('.csv', '.pkl'))
    os.makedirs(os.path.dirname(pickle_file), exist_ok=True)
    df.to_pickle(pickle_file)

csvs_df = pd.DataFrame(results)

# Add a column with the pickle file name
csvs_df['pkl_name'] = csvs_df['csv_name'].str.replace('.csv', '.pkl')

display(csvs_df)

list_file_name = '0_daep_files_list.pkl'
csvs_df.to_pickle(os.path.join(ROOT, 'pkl', 'daep', list_file_name))
csvs_df.to_csv(os.path.join(ROOT, 'datasets', list_file_name.replace('.pkl', '.csv')), index=False)
print(f"Saved file lists to {list_file_name} and {list_file_name.replace('.pkl', '.csv')}")
# Out:
#                                   csv_name  record_count  \
# 0    Additional_Information_by_Country.csv            49
# 1                  Australia_AEMO_2006.csv         17519
# 2                  Australia_AEMO_2007.csv         17520
# 3                  Australia_AEMO_2008.csv         17568
# 4                  Australia_AEMO_2009.csv         17520
# ..                                     ...           ...
# 501                       USA_SPP_2021.csv             0
# 502                       USA_SPP_2022.csv             0
# 503                       USA_SPP_2023.csv             0
# 504                       USA_SPP_2024.csv             0
# 505                       USA_SPP_2025.csv             0
#
#                                   pkl_name
# 0    Additional_Information_by_Country.pkl
# 1                  Australia_AEMO_2006.pkl
# 2                  Australia_AEMO_2007.pkl
# 3                  Australia_AEMO_2008.pkl
# 4                  Australia_AEMO_2009.pkl
# ..                                     ...
# 501                       USA_SPP_2021.pkl
# 502                       USA_SPP_2022.pkl
# 503                       USA_SPP_2023.pkl
# 504                       USA_SPP_2024.pkl
# 505                       USA_SPP_2025.pkl
#
# [506 rows x 3 columns]
# Saved file lists to 0_daep_files_list.pkl and 0_daep_files_list.csv

# %% [markdown]
# Loading a saved files index:

# %%
list_file_name = '0_daep_files_list.pkl'
csvs_df = pd.read_pickle(os.path.join(ROOT, 'pkl', 'daep', list_file_name))

# %% [markdown]
# ### Files list exploration

# %% [markdown]
# Exploring random segments.

# %%
sample_size = 10
start_idx = random.randint(0, len(csvs_df) - sample_size)
display(csvs_df.iloc[start_idx:start_idx + sample_size])
# Out:
#                 csv_name  record_count              pkl_name
# 77  Canada_IESO_2021.csv          8760  Canada_IESO_2021.pkl
# 78  Canada_IESO_2022.csv          8760  Canada_IESO_2022.pkl
# 79  Canada_IESO_2023.csv          8760  Canada_IESO_2023.pkl
# 80  Canada_IESO_2024.csv          8784  Canada_IESO_2024.pkl
# 81  Canada_IESO_2025.csv          2880  Canada_IESO_2025.pkl
# 82    Chile_CEN_2018.csv          8760    Chile_CEN_2018.pkl
# 83    Chile_CEN_2019.csv          8760    Chile_CEN_2019.pkl
# 84    Chile_CEN_2020.csv          8784    Chile_CEN_2020.pkl
# 85    Chile_CEN_2021.csv          8760    Chile_CEN_2021.pkl
# 86    Chile_CEN_2022.csv          8760    Chile_CEN_2022.pkl

# %% [markdown]
# Files with 2025 data:

# %%
csvs_2025 = csvs_df[csvs_df['csv_name'].str.contains('2025')]
print(len(csvs_2025), " files with 2025 price data:")
display(csvs_2025)
# Out:
# 14  files with 2025 price data:
#                          csv_name  record_count                      pkl_name
# 20        Australia_AEMO_2025.csv         43489       Australia_AEMO_2025.pkl
# 48       Brazil_ONS-CCEE_2025.csv          3696      Brazil_ONS-CCEE_2025.pkl
# 81           Canada_IESO_2025.csv          2880          Canada_IESO_2025.pkl
# 89             Chile_CEN_2025.csv          4381            Chile_CEN_2025.pkl
# 189            India_IEX_2025.csv         14496            India_IEX_2025.pkl
# 226           Japan_JEPX_2025.csv          8832           Japan_JEPX_2025.pkl
# 325       Singapore_NEMS_2025.csv          6768       Singapore_NEMS_2025.pkl
# 370      South Korea_KPX_2025.csv          4416      South Korea_KPX_2025.pkl
# 416            USA_CAISO_2025.csv          4199            USA_CAISO_2025.pkl
# 432            USA_ERCOT_2025.csv          3623            USA_ERCOT_2025.pkl
# 440  USA_ISO_NEW_ENGLAND_2025.csv          3623  USA_ISO_NEW_ENGLAND_2025.pkl
# 478            USA_NYISO_2025.csv          3719            USA_NYISO_2025.pkl
# 492              USA_PJM_2025.csv          3695              USA_PJM_2025.pkl
# 505              USA_SPP_2025.csv          2885              USA_SPP_2025.pkl

# %% [markdown]
# File content example:

# %%
country = "Spain"
market = "ENTSO-E"
year = 2019

price_data_df = pd.read_pickle(os.path.join(ROOT, 'pkl', 'daep', f'{country}_{market}_{year}.pkl'))
display(price_data_df.head(4))
print("...")
display(price_data_df.tail(4))
# Out:
#             Timestamp  Spain
# 0 2019-01-01 00:00:00  66.88
# 1 2019-01-01 01:00:00  66.88
# 2 2019-01-01 02:00:00  66.00
# 3 2019-01-01 03:00:00  63.64
# ...
#                Timestamp  Spain
# 8756 2019-12-31 20:00:00  42.58
# 8757 2019-12-31 21:00:00  39.74
# 8758 2019-12-31 22:00:00  38.88
# 8759 2019-12-31 23:00:00  37.37

# %% [markdown]
# ## Worldwide Electricity Load Dataset

# %% [markdown]
# This dataset provides a comprehensive, global-scale collection of time-series electricity load data aggregated from major power markets across Asia, Europe, North America, and Oceania. It captures system-level demand profiles at consistent temporal resolution, enabling detailed analysis of consumption patterns, peak-demand behavior, and seasonal variability across regions. The dataset is structured in a standardized and harmonized format to support load forecasting, cross-market comparative studies, and data-driven research in power system planning, operation, and energy market analytics.
#
# Ullah, Md Habib; Reza, Sayed Mohsin; Khan, Abdullah Al Ahad; Salekin, Siraj Us; Al-Bayati, Ali M. S.; Babaiahgari, Bhanu; Romero, David González; Molina, Jesús Rodríguez (2026), “Worldwide Electricity Load Dataset ”, Mendeley Data, V1, doi: 10.17632/ybggkc58fz.1

# %% [markdown]
# https://data.mendeley.com/datasets/ybggkc58fz/1

# %%
# Find all CSV files in the datasets/weld/ directory and subdirectories
csv_files = glob.glob(os.path.join(ROOT, 'datasets', 'weld', '**', '*.csv'), recursive=True)

# Create a list to store the results
results = []

# For each CSV file, get the file name and record count
for file_path in csv_files:
    file_name = os.path.basename(file_path)
    # Read the CSV file to get the record count
    df = pd.read_csv(file_path)
    record_count = len(df)
    results.append({'csv_name': file_name, 'record_count': record_count})
    print(f"Processed {file_name} with {record_count} records.")
    clear_output(wait=True)

    # Convert Timestamp column to datetime if it exists
    if 'Timestamp' in df.columns:
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])

    # Save as pickle file with same name but .pkl extension
    pickle_file = os.path.join(ROOT, 'pkl', 'weld', file_name.replace('.csv', '.pkl'))
    os.makedirs(os.path.dirname(pickle_file), exist_ok=True)
    df.to_pickle(pickle_file)

csvs_df = pd.DataFrame(results)

# Add a column with the pickle file name
csvs_df['pkl_name'] = csvs_df['csv_name'].str.replace('.csv', '.pkl')

display(csvs_df)

list_file_name = '0_weld_files_list.pkl'
csvs_df.to_pickle(os.path.join(ROOT, 'pkl', 'weld', list_file_name))
print(f"Saved file list to {os.path.join(ROOT, 'pkl', 'weld', list_file_name)}")
# Out:
#                        csv_name  record_count                    pkl_name
# 0    Additional_Information.csv            42  Additional_Information.pkl
# 1       Australia_AEMO_2006.csv         17519     Australia_AEMO_2006.pkl
# 2       Australia_AEMO_2007.csv         17520     Australia_AEMO_2007.pkl
# 3       Australia_AEMO_2008.csv         17568     Australia_AEMO_2008.pkl
# 4       Australia_AEMO_2009.csv         17520     Australia_AEMO_2009.pkl
# ..                          ...           ...                         ...
# 484            USA_SPP_2021.csv          8758            USA_SPP_2021.pkl
# 485            USA_SPP_2022.csv          8749            USA_SPP_2022.pkl
# 486            USA_SPP_2023.csv          8757            USA_SPP_2023.pkl
# 487            USA_SPP_2024.csv          8782            USA_SPP_2024.pkl
# 488            USA_SPP_2025.csv          7351            USA_SPP_2025.pkl
#
# [489 rows x 3 columns]
# Saved file list to ..\pkl\weld\0_weld_files_list.pkl

# %% [markdown]
# Loading a saved files index:

# %%
list_file_name = '0_weld_files_list.pkl'
csvs_df = pd.read_pickle(os.path.join(ROOT, 'pkl', 'weld', list_file_name))

# %% [markdown]
# ### Files list exploration

# %% [markdown]
# Exploring random segments.

# %%
sample_size = 10
start_idx = random.randint(0, len(csvs_df) - sample_size)
# start_idx = 259
display(csvs_df.iloc[start_idx:start_idx + sample_size])
# Out:
#                csv_name  record_count            pkl_name
# 436   USA_MISO_2018.csv        103464   USA_MISO_2018.pkl
# 437   USA_MISO_2019.csv        103463   USA_MISO_2019.pkl
# 438   USA_MISO_2020.csv         41521   USA_MISO_2020.pkl
# 439   USA_MISO_2021.csv        104467   USA_MISO_2021.pkl
# 440   USA_MISO_2022.csv        103223   USA_MISO_2022.pkl
# 441   USA_MISO_2023.csv         98623   USA_MISO_2023.pkl
# 442   USA_MISO_2024.csv        103983   USA_MISO_2024.pkl
# 443   USA_MISO_2025.csv         10285   USA_MISO_2025.pkl
# 444  USA_NYISO_2001.csv         85256  USA_NYISO_2001.pkl
# 445  USA_NYISO_2002.csv        139935  USA_NYISO_2002.pkl

# %% [markdown]
# Files with 2025 data:

# %%
csvs_2025 = csvs_df[csvs_df['csv_name'].str.contains('2025')]
print(len(csvs_2025), " files with 2025 load data:")
display(csvs_2025)
# Out:
# 41  files with 2025 load data:
#                              csv_name  record_count  \
# 20            Australia_AEMO_2025.csv         43489
# 31           Austria_ENTSO-E_2025.csv         15346
# 42           Belgium_ENTSO-E_2025.csv         15347
# 53          Bulgaria_ENTSO-E_2025.csv          3836
# 76               CANADA_IESO_2025.csv          3815
# 87           Croatia_ENTSO-E_2025.csv         15347
# 98    Czech Republic_ENTSO-E_2025.csv         15348
# 109          Denmark_ENTSO-E_2025.csv          3837
# 120          Estonia_ENTSO-E_2025.csv          3837
# 131          Finland_ENTSO-E_2025.csv         15348
# 142           France_ENTSO-E_2025.csv         15348
# 153          Germany_ENTSO-E_2025.csv         15348
# 164           Greece_ENTSO-E_2025.csv          3838
# 175          Hungary_ENTSO-E_2025.csv         15354
# 186          Ireland_ENTSO-E_2025.csv          7676
# 197            Italy_ENTSO-E_2025.csv         15351
# 216           Latvia_ENTSO-E_2025.csv          3838
# 227        Lithuania_ENTSO-E_2025.csv         15355
# 238       Luxembourg_ENTSO-E_2025.csv         15354
# 249       Montenegro_ENTSO-E_2025.csv          3838
# 260      Netherlands_ENTSO-E_2025.csv         15354
# 271  North Macedonia_ENTSO-E_2025.csv          3838
# 282           Norway_ENTSO-E_2025.csv          9879
# 293           Poland_ENTSO-E_2025.csv         20740
# 304         Portugal_ENTSO-E_2025.csv          3839
# 315          Romania_ENTSO-E_2025.csv         15357
# 326           Serbia_ENTSO-E_2025.csv          3839
# 332           Singapore_NEMS_2025.csv          7344
# 343         Slovakia_ENTSO-E_2025.csv          3839
# 354         Slovenia_ENTSO-E_2025.csv          3839
# 365            Spain_ENTSO-E_2025.csv         15359
# 376           Sweden_ENTSO-E_2025.csv          3838
# 387      Switzerland_ENTSO-E_2025.csv          3839
# 398   United Kingdom_ENTSO-E_2025.csv          7677
# 403                USA_CAISO_2025.csv          4149
# 427                USA_ERCOT_2025.csv          6991
# 434      USA_ISO_NEW_ENGLAND_2025.csv          5174
# 443                 USA_MISO_2025.csv         10285
# 468                USA_NYISO_2025.csv        105822
# 473                  USA_PJM_2025.csv          4079
# 488                  USA_SPP_2025.csv          7351
#
#                              pkl_name
# 20            Australia_AEMO_2025.pkl
# 31           Austria_ENTSO-E_2025.pkl
# 42           Belgium_ENTSO-E_2025.pkl
# 53          Bulgaria_ENTSO-E_2025.pkl
# 76               CANADA_IESO_2025.pkl
# 87           Croatia_ENTSO-E_2025.pkl
# 98    Czech Republic_ENTSO-E_2025.pkl
# 109          Denmark_ENTSO-E_2025.pkl
# 120          Estonia_ENTSO-E_2025.pkl
# 131          Finland_ENTSO-E_2025.pkl
# 142           France_ENTSO-E_2025.pkl
# 153          Germany_ENTSO-E_2025.pkl
# 164           Greece_ENTSO-E_2025.pkl
# 175          Hungary_ENTSO-E_2025.pkl
# 186          Ireland_ENTSO-E_2025.pkl
# 197            Italy_ENTSO-E_2025.pkl
# 216           Latvia_ENTSO-E_2025.pkl
# 227        Lithuania_ENTSO-E_2025.pkl
# 238       Luxembourg_ENTSO-E_2025.pkl
# 249       Montenegro_ENTSO-E_2025.pkl
# 260      Netherlands_ENTSO-E_2025.pkl
# 271  North Macedonia_ENTSO-E_2025.pkl
# 282           Norway_ENTSO-E_2025.pkl
# 293           Poland_ENTSO-E_2025.pkl
# 304         Portugal_ENTSO-E_2025.pkl
# 315          Romania_ENTSO-E_2025.pkl
# 326           Serbia_ENTSO-E_2025.pkl
# 332           Singapore_NEMS_2025.pkl
# 343         Slovakia_ENTSO-E_2025.pkl
# 354         Slovenia_ENTSO-E_2025.pkl
# 365            Spain_ENTSO-E_2025.pkl
# 376           Sweden_ENTSO-E_2025.pkl
# 387      Switzerland_ENTSO-E_2025.pkl
# 398   United Kingdom_ENTSO-E_2025.pkl
# 403                USA_CAISO_2025.pkl
# 427                USA_ERCOT_2025.pkl
# 434      USA_ISO_NEW_ENGLAND_2025.pkl
# 443                 USA_MISO_2025.pkl
# 468                USA_NYISO_2025.pkl
# 473                  USA_PJM_2025.pkl
# 488                  USA_SPP_2025.pkl

# %% [markdown]
# File content example:

# %%
country = "Spain"
market = "ENTSO-E"
year = 2021

load_data_df = pd.read_pickle(os.path.join(ROOT, 'pkl', 'weld', f'{country}_{market}_{year}.pkl'))
display(load_data_df.head(6))
print("...")
display(load_data_df.tail(6))
# Out:
#             Timestamp    Spain
# 0 2021-01-01 00:00:00  24623.0
# 1 2021-01-01 01:00:00  23436.0
# 2 2021-01-01 02:00:00  21319.0
# 3 2021-01-01 03:00:00  19606.0
# 4 2021-01-01 04:00:00  18753.0
# 5 2021-01-01 05:00:00  18566.0
# ...
#                Timestamp    Spain
# 8755 2021-12-31 18:00:00  26959.0
# 8756 2021-12-31 19:00:00  27863.0
# 8757 2021-12-31 20:00:00  27661.0
# 8758 2021-12-31 21:00:00  26551.0
# 8759 2021-12-31 22:00:00  23743.0
# 8760 2021-12-31 23:00:00  22220.0
